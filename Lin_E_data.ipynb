# %%
# !ls Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
tndb_df = pd.read_csv('Data/tn.movie_budgets.csv')
tn_mov_df = pd.read_csv('Data/tmdb.movies.csv')
akas_df = pd.read_csv('Data/imdb.title.akas.csv')
#import the three schemas to compare imdb to tndb

display(tndb_df.head(1))
display(tn_mov_df.head(1))
display(akas_df.head(1))


#display(tndb_df.head(30))
#display(tn_mov_df.sort_values(by ='id', ascending = True).head())
#tn_mov_df.head(2)
# Out:
#    id  release_date   movie production_budget domestic_gross worldwide_gross
# 0   1  Dec 18, 2009  Avatar      $425,000,000   $760,507,625  $2,776,345,279
#    Unnamed: 0        genre_ids     id original_language  \
# 0           0  [12, 14, 10751]  12444                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
#     title_id  ordering          title region language types attributes  \
# 0  tt0369610        10  Джурасик свят     BG       bg   NaN        NaN
#
#    is_original_title
# 0                0.0

# %%
#tn_db = tn_mov_df.join(tndb_df, on='id', how = 'left',lsuffix = " combined")
#tn_db.head()

# %%
tndb_df["Mov_name"] = tndb_df['movie'].str.lower().str.replace('[ \'\:\,\.]','').astype(str)
    #creates a new column named Mov_name in the tn_df and strip the movie titles of all
    #punctuation and spaces to be compared with akas_df
tn_mov_df["Mov_name"] = tn_mov_df['title'].str.lower().str.replace('[ \'\:\,\.]','').astype(str)
akas_df["Mov_name"] = akas_df['title'].str.lower().str.replace('[ \'\:\,\.]','').astype(str)


#display(akas_df)
#tn_mov_df.head(1)

# %%
display(tndb_df.head(1))
display(tn_mov_df.head(1))
akas_df.head(1)
# Out:
#    id  release_date   movie production_budget domestic_gross worldwide_gross  \
# 0   1  Dec 18, 2009  Avatar      $425,000,000   $760,507,625  $2,776,345,279
#
#   Mov_name
# 0   avatar
#    Unnamed: 0        genre_ids     id original_language  \
# 0           0  [12, 14, 10751]  12444                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
#
#                                           title  vote_average  vote_count  \
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
#
#                                Mov_name
# 0  harrypotterandthedeathlyhallowspart1
#     title_id  ordering          title region language types attributes  \
# 0  tt0369610        10  Джурасик свят     BG       bg   NaN        NaN
#
#    is_original_title      Mov_name
# 0                0.0  джурасиксвят

# %%
tn_db = tn_mov_df.merge(tndb_df, on = 'Mov_name', how = 'left')
tn_db.head()
# Out:
#    Unnamed: 0            genre_ids   id_x original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date_x  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533     2010-11-19
# 1                      How to Train Your Dragon      28.734     2010-03-26
# 2                                    Iron Man 2      28.515     2010-05-07
# 3                                     Toy Story      28.005     1995-11-22
# 4                                     Inception      27.920     2010-07-16
#
#                                           title  vote_average  vote_count  \
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186
#
#                                Mov_name  id_y release_date_y  \
# 0  harrypotterandthedeathlyhallowspart1   NaN            NaN
# 1                  howtotrainyourdragon  30.0   Mar 26, 2010
# 2                              ironman2  15.0    May 7, 2010
# 3                              toystory  37.0   Nov 22, 1995
# 4                             inception  38.0   Jul 16, 2010
#
#                       movie production_budget domestic_gross worldwide_gross
# 0                       NaN               NaN            NaN             NaN
# 1  How to Train Your Dragon      $165,000,000   $217,581,232    $494,870,992
# 2                Iron Man 2      $170,000,000   $312,433,331    $621,156,389
# 3                 Toy Story       $30,000,000   $191,796,233    $364,545,516
# 4                 Inception      $160,000,000   $292,576,195    $835,524,642

# %%
#tn_db.info()

tn_imdb_db = akas_df.merge(tn_db, on = 'Mov_name', how = 'left')
tn_imdb_db.info()
tn_imdb_db.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341779 entries, 0 to 341778
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           341779 non-null  object
#  1   ordering           341779 non-null  int64
#  2   title_x            341779 non-null  object
#  3   region             286129 non-null  object
#  4   language           43252 non-null   object
#  5   types              174415 non-null  object
#  6   attributes         15258 non-null   object
#  7   is_original_title  341754 non-null  float64
#  8   Mov_name           341779 non-null  object
#  9   Unnamed: 0         50455 non-null   float64
#  10  genre_ids          50455 non-null   object
#  11  id_x               50455 non-null   float64
#  12  original_language  50455 non-null   object
#  13  original_title     50455 non-null   object
#  14  popularity         50455 non-null   float64
#  15  release_date_x     50455 non-null   object
#  16  title_y            50455 non-null   object
#  17  vote_average       50455 non-null   float64
#  18  vote_count         50455 non-null   float64
#  19  id_y               13160 non-null   float64
#  20  release_date_y     13160 non-null   object
#  21  movie              13160 non-null   object
#  22  production_budget  13160 non-null   object
#  23  domestic_gross     13160 non-null   object
#  24  worldwide_gross    13160 non-null   object
# dtypes: float64(7), int64(1), object(17)
# memory usage: 67.8+ MB
#     title_id  ordering                                  title_x region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
# 5  tt0369610        15                           Jurassic World     GR
# 6  tt0369610        16                           Jurassic World     IT
# 7  tt0369610        17                            Jurski svijet     HR
# 8  tt0369610        18                             Olam ha'Yura     IL
# 9  tt0369610        19           Jurassic World: Mundo Jurásico     MX
#
#   language        types   attributes  is_original_title  \
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0
# 5      NaN  imdbDisplay          NaN                0.0
# 6      NaN  imdbDisplay          NaN                0.0
# 7      NaN  imdbDisplay          NaN                0.0
# 8       he  imdbDisplay          NaN                0.0
# 9      NaN  imdbDisplay          NaN                0.0
#
#                             Mov_name  Unnamed: 0  ... release_date_x  \
# 0                       джурасиксвят         NaN  ...            NaN
# 1                   jurashikkuwarudo         NaN  ...            NaN
# 2  jurassicworldomundodosdinossauros         NaN  ...            NaN
# 3               omundodosdinossauros         NaN  ...            NaN
# 4                      jurassicworld     14193.0  ...     2015-06-12
# 5                      jurassicworld     14193.0  ...     2015-06-12
# 6                      jurassicworld     14193.0  ...     2015-06-12
# 7                       jurskisvijet         NaN  ...            NaN
# 8                         olamhayura         NaN  ...            NaN
# 9         jurassicworldmundojurásico         NaN  ...            NaN
#
#           title_y vote_average vote_count  id_y release_date_y  \
# 0             NaN          NaN        NaN   NaN            NaN
# 1             NaN          NaN        NaN   NaN            NaN
# 2             NaN          NaN        NaN   NaN            NaN
# 3             NaN          NaN        NaN   NaN            NaN
# 4  Jurassic World          6.6    14056.0  34.0   Jun 12, 2015
# 5  Jurassic World          6.6    14056.0  34.0   Jun 12, 2015
# 6  Jurassic World          6.6    14056.0  34.0   Jun 12, 2015
# 7             NaN          NaN        NaN   NaN            NaN
# 8             NaN          NaN        NaN   NaN            NaN
# 9             NaN          NaN        NaN   NaN            NaN
#
#             movie  production_budget  domestic_gross  worldwide_gross
# 0             NaN                NaN             NaN              NaN
# 1             NaN                NaN             NaN              NaN
# 2             NaN                NaN             NaN              NaN
# 3             NaN                NaN             NaN              NaN
# 4  Jurassic World       $215,000,000    $652,270,625   $1,648,854,864
# 5  Jurassic World       $215,000,000    $652,270,625   $1,648,854,864
# 6  Jurassic World       $215,000,000    $652,270,625   $1,648,854,864
# 7             NaN                NaN             NaN              NaN
# 8             NaN                NaN             NaN              NaN
# 9             NaN                NaN             NaN              NaN
#
# [10 rows x 25 columns]

# %%
#tn_df['Mov_name'] = tn_df['Mov_name'].str.replace('[ \'\:\,\.]','')

# %%
#tn_info_df = tn_mov_df.join(tndb_df, how = "inner")
