# %%
cd ../../

# %%
from tools.data_preparation import *

# %%
reviews_df = clean_rt_reviews()
info_df = clean_rt_movie_info()

# %%
rt_df = info_df.merge(reviews_df, on='id')
rt_df
# Out:
#          id                                           synopsis rating  \
# 0         3  New York City, not-too-distant-future: Eric Pa...      R
# 1         3  New York City, not-too-distant-future: Eric Pa...      R
# 2         3  New York City, not-too-distant-future: Eric Pa...      R
# 3         3  New York City, not-too-distant-future: Eric Pa...      R
# 4         3  New York City, not-too-distant-future: Eric Pa...      R
# ...     ...                                                ...    ...
# 54418  2000  Suspended from the force, Paris cop Hubert is ...      R
# 54419  2000  Suspended from the force, Paris cop Hubert is ...      R
# 54420  2000  Suspended from the force, Paris cop Hubert is ...      R
# 54421  2000  Suspended from the force, Paris cop Hubert is ...      R
# 54422  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                    genre theater_date  \
# ...

# %%
genre_popularity_df = rt_df[['id', 'genre', 'fresh']]
genre_popularity_df.head()
# Out:
#    id                                 genre  fresh
# 0   3  (Drama, Science Fiction and Fantasy)      1
# 1   3  (Drama, Science Fiction and Fantasy)      0
# 2   3  (Drama, Science Fiction and Fantasy)      1
# 3   3  (Drama, Science Fiction and Fantasy)      1
# 4   3  (Drama, Science Fiction and Fantasy)      1

# %%
genres = rt_df['genre'].unique()
unique_genres = set()
for item in genres:
    unique_genres.update(set(item))
unique_genres
# Out:
# {'Action and Adventure',
#  'Animation',
#  'Anime and Manga',
#  'Art House and International',
#  'Classics',
#  'Comedy',
#  'Cult Movies',
#  'Documentary',
#  'Drama',
#  'Faith and Spirituality',
#  'Gay and Lesbian',
#  'Horror',
#  'Kids and Family',
#  'Musical and Performing Arts',
#  'Mystery and Suspense',
#  'Not listed',
#  'Romance',
#  'Science Fiction and Fantasy',
#  'Special Interest',
#  'Sports and Fitness',
#  'Television',
#  'Western'}

# %%
exploded = genre_popularity_df.explode('genre', ignore_index=True)
exploded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120054 entries, 0 to 120053
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      120054 non-null  int64
#  1   genre   120054 non-null  object
#  2   fresh   120054 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 2.7+ MB

# %%
grouped = exploded.groupby('genre')['fresh'].aggregate(['count', 'sum', 'mean'])

# %%
sort_by_percent = grouped.sort_values('mean', ascending=False)

# %%
sort_by_percent.head()
# Out:
#                  count   sum      mean
# genre
# Gay and Lesbian     42    36  0.857143
# Cult Movies         54    46  0.851852
# Documentary       1116   864  0.774194
# Classics          2121  1637  0.771806
# Not listed          87    66  0.758621

# %%
sort_by_num_positive = grouped.sort_values('sum', ascending=False)
sort_by_num_positive.head()
# Out:
#                       count    sum      mean
# genre
# Drama                 33595  21942  0.653133
# Comedy                21798  12878  0.590788
# Action and Adventure  12908   7334  0.568175
# Mystery and Suspense  11742   6874  0.585420
# Romance                8088   5168  0.638971

# %%
tn_df = pd.read_csv(TN_BUDGETS)
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
tn_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
display_percent_nan(tn_df)
# Out:
# id: 0.00 % null
# release_date: 0.00 % null
# movie: 0.00 % null
# production_budget: 0.00 % null
# domestic_gross: 0.00 % null
# worldwide_gross: 0.00 % null

# %%
tn_df = clean_tn_budgets()

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   int64
#  5   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 271.2+ KB
